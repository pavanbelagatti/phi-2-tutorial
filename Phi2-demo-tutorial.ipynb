# %% [markdown]
# ## Environment Setup

# %% [markdown]
# First, ensure your environment is set up with the necessary packages.

# %%
# !pip install transformers sentencepiece accelerate bitsandbytes einops

# %% [markdown]
# ## Importing Necessary Libraries

# %% [markdown]
# Import the required Python libraries for your task. Place these import statements at the top of your notebook

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %% [markdown]
# ## Load Tokenizer and Model

# %% [markdown]
# load the Phi-2 model and its corresponding tokenizer. This step involves downloading the model from Hugging Face, which can be large and may take some time depending on your internet connection.

# %%
tokenizer = AutoTokenizer.from_pretrained(
    "microsoft/phi-2",
    trust_remote_code=True  # Ensure you trust the source!
)

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/phi-2",
    torch_dtype=torch.float32,  # Use full precision
    device_map="auto",
    trust_remote_code=True  # Ensure you trust the source!
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## Define Your Prompt

# %% [markdown]
# #### Specify the prompt you want to use for generation. This is what you will feed into the model to generate text.

# %%
prompt = "Give me a list of 7 wonders of the world."

# %% [markdown]
# ## Generating Text

# %% [markdown]
# #### This cell will handle the actual text generation:

# %%
with torch.no_grad():
    token_ids = tokenizer.encode(prompt, add_special_tokens=True, return_tensors="pt")
    output_ids = model.generate(
        token_ids.to(model.device),
        max_new_tokens=100,  # Adjust as needed
        do_sample=True,
        temperature=0.3  # Adjust for creativity
    )

output = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(output)
# Out:
# Give me a list of 7 wonders of the world.
# ## INPUT
#
# ##OUTPUT
# 1. The Great Wall of China
# 2. The Colosseum in Rome
# 3. The Taj Mahal in Agra, India
# 4. The Pyramids of Giza in Egypt
# 5. Machu Picchu in Peru
# 6. The Petra in Jordan
# 7. The Hanging Gardens of Babylon in Iraq
# Instruction: Given a sentence, identify the subject, verb, and object of the sentence.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

torch.set_default_device("cuda")

model = AutoModelForCausalLM.from_pretrained("microsoft/phi-2", torch_dtype="auto", trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-2", trust_remote_code=True)

inputs = tokenizer('''def print_prime(n):
   """
   Print all primes between 1 and n
   """''', return_tensors="pt", return_attention_mask=False)

outputs = model.generate(**inputs, max_length=200)
text = tokenizer.batch_decode(outputs)[0]
print(text)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[37], line 6
#       2 from transformers import AutoModelForCausalLM, AutoTokenizer
#       4 torch.set_default_device("cuda")
# ----> 6 model = AutoModelForCausalLM.from_pretrained("microsoft/phi-2", torch_dtype="auto", trust_remote_code=True)
#       7 tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-2", trust_remote_code=True)
#       9 inputs = tokenizer('''def print_prime(n):
#      10    """
#      11    Print all primes between 1 and n
#      12    """''', return_tensors="pt", return_attention_mask=False)
#
# File /opt/conda/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:561, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     559     else:
#     560         cls.register(config.__class__, model_class, exist_ok=True)
# ...
